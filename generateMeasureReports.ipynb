# %% [markdown]
# Script to generate and push MeasureReport resources

# %%
import json
import requests
from fhirpathpy import compile
from jsonpath_ng import parse
from copy import copy, deepcopy
from datetime import datetime
from dateutil.relativedelta import relativedelta
from dateutil import parser
import random
import uuid
from typing import List
from re import findall
import os

# %%
class MeasureReport:
    def __init__(self, template:str):
        self.template = template
        # Get all text from pattern like "$string123"
        self.fields = findall("\"\$([A-Za-z\d]+?)\"", self.template)

    def subject(self, subject, contained=None):
        template = json.loads(self.template)
        if contained is not None:
            if 'contained' in template:
                template['contained'].append(contained)
            else:
                template['contained'] = [contained]
        template['subject'] = subject
        self.template = json.dumps(template)

    def report(self, values:dict):
        temp = str(self.template)
        for field in self.fields:
            value = values.get(field, 0)
            temp = temp.replace(f'"${field}"', str(value))
        return temp

class MeasureReportSubject:
    def __init__(self, subject=None, beds=None, icu_beds=None, ventilators=None, reports:List[MeasureReport]=[]):
        if icu_beds is not None and beds is not None and icu_beds > beds:
            raise ValueError("Total beds must be greater than or equal to beds of a specific type")
        
        beds_min = 50
        beds_max = 500
        if beds is None:
            beds = random.randint(beds_min, beds_max)
        
        icu_beds_min = 2
        icu_beds_max = round(beds * 0.75)
        if icu_beds is None:
            icu_beds = random.randint(icu_beds_min, icu_beds_max)
        
        ventilators_min = 2
        ventilators_max = round(beds * 0.5)
        if ventilators is None:
            ventilators = random.randint(ventilators_min, ventilators_max)

        subject_name = ""
        subject_contained = None
        subject_reference = None

        if subject is None:
                subject = str(uuid.uuid4())
        if isinstance(subject, str) or isinstance(subject, int):
            if isinstance(subject, str) and "/" in subject:
                subject_name = subject.split("/_history")[0].split("/")[-1]
                subject_reference = {
                    "reference": subject,
                    "display": f"Hospital {subject_name}"
                }
            else:
                subject_id = f"hospital{subject}"
                subject_name = f"Hospital {subject}"
                subject_contained = {
                    "resourceType": "Location",
                    "id": subject_id,
                    "name": subject_name,
                    "managingOrganization": {
                        "display": "WA State Department of Health"
                    }
                }

                subject_reference = {
                    "reference": f"#{subject_id}",
                    "display": subject_name
                }
        else:
            subject_contained = subject
            subject_reference = {
                "reference": subject["id"],
                "display": subject["name"]
            }
            subject_name = subject["name"]

        for report in reports:
            report.subject(subject_reference, subject_contained)

        self.subject_name = subject_name
        self.beds = beds # All beds
        self.icu_beds = icu_beds # ICU subset
        self.ventilators = ventilators
        self.reports = reports
        self.values = {}

    def update(self, date, start, end): 
        values = {}

        values['date'] = date
        values['start'] = start
        values['end'] = end

        values['numVent'] = self._try_or_value(lambda: random.randint(0, self.ventilators), 0)
        values['numVentUse'] = self.ventilators - values['numVent']

        values['numBedsOcc'] = self._try_or_value(lambda: random.randint(values['numVentUse'], self.beds), values['numVentUse'])
        values['numICUBedsOcc'] = self._try_or_value(lambda: random.randint(0, min(self.icu_beds, values['numBedsOcc'])), 0)
        values['numICUBedsAvail'] = self.icu_beds - values['numICUBedsOcc']
        values['numNonICUBedsOcc'] = values['numBedsOcc'] - values['numICUBedsOcc']

        values['numC19MechVentPats'] = self._try_or_value(lambda: random.randint(0, values['numVentUse']), 0)
        values['numC19HospPats'] = self._try_or_value(lambda: random.randint(values['numC19MechVentPats'], values['numBedsOcc']), values['numC19MechVentPats'])
        values['numC19HOPats'] = self._try_or_value(lambda: random.randint(0, values['numC19HospPats']), 0)
        values['numC19OFMechVentPats'] = self._try_or_value(lambda: random.randint(0, min(values['numNonICUBedsOcc'], values['numVentUse'] - values['numC19MechVentPats'])), 0)
        values['numC19OverflowPats'] = self._try_or_value(lambda: random.randint(values['numC19OFMechVentPats'], values['numNonICUBedsOcc']), values['numC19OFMechVentPats'])
        values['numC19Died'] = random.randint(0, 20)
        values['numC19Pats'] = self._try_or_value(lambda: random.randint(values['numC19HospPats'], self.beds), self.beds)
        values['numC19VentPats'] = values['numC19MechVentPats'] + values['numC19OFMechVentPats']

        values['totalOrdersIncrease'] = random.randint(5, self.beds * 3)
        values['totalTestResultsIncrease'] = max(1, round(values['totalOrdersIncrease'] * round(random.randint(10, 70)/100, 2)))
        values['positiveIncrease'] = self._try_or_value(lambda: random.randint(0, values['totalTestResultsIncrease']), 0)
        values['positiveIncreasePercent'] = round(values['positiveIncrease'] / values['totalTestResultsIncrease'], 2)

        # TODO accumulate over time
        values['totalOrders'] = values['totalOrdersIncrease']
        values['rejected'] = values['totalOrders'] - values['totalTestResultsIncrease']
        values['totalTestResults'] = values['totalTestResultsIncrease'] 
        values['positive'] = values['positiveIncrease']
        values['positivePercent'] = round(values['positive'] / values['totalTestResults'], 2)

        self.values = values

    def report(self, date:str, start:str, end:str):
        measure_reports = []
        self.update(date, start, end)
        for report in self.reports:
            measure_reports.append(report.report(self.values))
        return measure_reports
    
    def _try_or_value(self, lam, val):
        try:
            return lam()
        except ValueError:
            return val

# %%
def write_entries(entries, filename):
    with open(filename, 'a') as f:
        entries_string = ""
        entries_string = "\n".join(entries)
        f.write(entries_string+"\n")

# %%
def generateMeasureReports(subjects:List[MeasureReportSubject], start:datetime, end:datetime, period:relativedelta, folder):
    dt_format = "%Y-%m-%dT%H:%M:%S+00:00"
    generation_time = f'"{datetime.now().strftime(dt_format)}"'
    end_period = period - relativedelta(seconds=1)
    for subject in subjects:
        entries = []
        iter_start = copy(start)
        iter_end = iter_start + end_period
        outfile = f"{folder}/{subject.subject_name.replace(' ', '_')}.ndjson"
        while iter_start < end:
            entries.extend(subject.report(generation_time, f'"{iter_start.strftime(dt_format)}"', f'"{iter_end.strftime(dt_format)}"'))
            iter_start = iter_start + period
            iter_end = iter_start + end_period
        write_entries(entries, outfile)

# %%
template_files = [
    "template_CDCPatientImpactAndHospitalCapacity.json",
    "template_FEMADailyHospitalCOVID19Reporting.json",
    "template_ICUBedsReporting.json",
    "template_ICUBedCurrentOccupancy.json",
    "template_ICUBedStaffedCapacity.json",
]

template_json = []

for filename in template_files:
    with open(filename, 'r') as file:
        template_json.append(file.read())

# %%
reports = [ MeasureReport(template) for template in template_json ]
start = parser.parse("2021-01-01T00:00:00+00:00")
end = parser.parse("2022-01-01T00:00:00+00:00")
period = relativedelta(days=1)
num_subjects = 100
subjects = [ MeasureReportSubject(subject, reports=deepcopy(reports)) for subject in range(num_subjects) ]

# %%
folder = f"test_data/entries_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
if not os.path.isdir(folder):
    os.makedirs(folder)
with open(f'{folder}/Subjects.json', 'w') as file:
    subject_info_list = []
    for subject in subjects:
        subject_info = {
            "name": subject.subject_name,
            "beds": subject.beds,
            "icu_beds": subject.icu_beds,
            "ventilators": subject.ventilators,
        }
        subject_info_list.append(subject_info)
    file.write(json.dumps(subject_info_list, indent=4))
generateMeasureReports(subjects, start, end, period, folder)

# %%
raise SystemExit("Execution stopped.")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Execution stopped.

# %%
ndjson = True

with open(f'entries_{datetime.now().strftime("%Y%m%d_%H%M%S")}.{"nd" if ndjson else ""}json', 'w') as f:
    entries_string = ""
    if ndjson:
        json_entries = [json.dumps(entry) for entry in entries]
        entries_string = "\n".join(json_entries)
    else:
        entries_string = json.dumps(entries, indent=None, separators=(',', ':'))

    f.write(entries_string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 6
#       4 entries_string = ""
#       5 if ndjson:
# ----> 6     json_entries = [json.dumps(entry) for entry in entries]
#       7     entries_string = "\n".join(json_entries)
#       8 else:
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ### Access MeasureReports on agg-data server

# %%
base_url = "https://fhir.agg-data.connectathon.dev.cirg.uw.edu"
fhir_endpoint = f'{base_url}/fhir'
resource_type = "MeasureReport"
search_params = {
    "date": "ge2020-01-01",
    "_count": "1000",
}
headers = {
    "Content-Type": "application/json+fhir"
}
full_url = f'{fhir_endpoint}/{resource_type}'

# %%
cred_manager = None

# %%
# phdi attempt: SLOW performance, moved to requests library
# entries = []
# tmp_search_url = full_search_url
# while tmp_search_url is not None:
#     (page_entries, search_url) = extract_data_from_fhir_search_incremental(search_url=tmp_search_url, cred_manager=cred_manager)
#     entries.append(page_entries)

# %%
entries = []
url = full_url

get_entries = compile("Bundle.entry")

next_url_exists = compile("Bundle.link.where(relation='next').exists()")
check_next_url = lambda x: next_url_exists(x)[0]

next_url_path = compile("Bundle.link.where(relation='next').url")
get_next_url = lambda x: next_url_path(x)[0]

while True:
    if (url == full_url):
        response = requests.get(url=full_url, params=search_params, headers=headers)
    else:
        response = requests.get(url=url, headers=headers)
    content = json.loads(response.content)
    entries.extend(get_entries(content))
    #update the url
    if check_next_url(content):
        url = get_next_url(content)
        print(url)
    else:
        break

# %%
print(response.status_code)
if response.status_code >= 400:
        print(response.text)
# Out:
# 500
# {
#   "resourceType": "OperationOutcome",
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><h1>Operation Outcome</h1><table border=\"0\"><tr><td style=\"font-weight: bold;\">ERROR</td><td>[]</td><td><pre>Failed to call access method: org.springframework.transaction.CannotCreateTransactionException: Could not open JPA EntityManager for transaction; nested exception is org.hibernate.exception.JDBCConnectionException: Unable to acquire JDBC Connection</pre></td>\n\t\t\t</tr>\n\t\t</table>\n\t</div>"
#   },
#   "issue": [ {
#     "severity": "error",
#     "code": "processing",
#     "diagnostics": "Failed to call access method: org.springframework.transaction.CannotCreateTransactionException: Could not open JPA EntityManager for transaction; nested exception is org.hibernate.exception.JDBCConnectionException: Unable to acquire JDBC Connection"
#   } ]
# }

# %%
len(entries)
# Out:
# 2715

# %%
measureSet = set()
for entry in entries:
    measureSet.add(entry['resource']['measure'])
list(measureSet)
# Out:
# ['http://hl7.org/fhir/uv/saner/Measure/CDCPatientImpactAndHospitalCapacity',
#  'https://cqf-ruler.ecqm.icfcloud.com/fhir/Measure/ICUBedsReporting',
#  'https://cqf-ruler.ecqm.icfcloud.com/fhir/Measure/ICUBedStaffedCapacity',
#  'http://hl7.org/fhir/uv/saner/Measure/FEMADailyHospitalCOVID19Reporting',
#  'https://cqf-ruler.ecqm.icfcloud.com/fhir/Measure/ICUBedCurrentOccupancy']

# %%
measures_to_replace = []
#     'ICUBedStaffedCapacity',
#     'ICUBedCurrentOccupancy',
#     'ICUBedsReporting'
# ]
updateBundle = {
    "resourceType": "Bundle",
	"id": "mr-update",
	"type": "transaction",
	"entry": []
}
measure_report_measure = compile("MeasureReport.measure")
get_measure = lambda x: measure_report_measure(x)[0]

# %%
for measure in measureSet:
    for entry in entries:
        if get_measure(entry['resource']) == measure:
            print(entry['resource'])
            break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for measure in measureSet:
#       2     for entry in entries:
#       3         if get_measure(entry['resource']) == measure:
#
# NameError: name 'measureSet' is not defined

# %%
fields = {
    "ICUBedCurrentOccupancy": {
        "template": "template_ICUBedCurrentOccupancy.json",
        "parameters": {
            # Datetime of first MeasureReport
            "reporting_start": "2023-01-01T00:00:00+00:00",
            # Maximum datetime of MeasureReports
            "reporting_end": "2023-12-31T23:00:00+00:00",
            # Reporting period time delta
            "period": "0000-00-00T00:00:00+00:00",
            "subject": {
                "reference": "Location/helios1",
                "identifier": {
                    "value": "Helios1",
                },
                "display": "Helios Test Facility 1",
            },
        }
    }
}

# %%
len(entries)
# Out:
# 18250

# %%
entries[0]
# Out:
# {'resourceType': 'MeasureReport',
#  'status': 'complete',
#  'type': 'summary',
#  'measure': 'http://hl7.org/fhir/uv/saner/Measure/CDCPatientImpactAndHospitalCapacity',
#  'subject': {'reference': 'Location/hospital0',
#   'identifier': {'value': 'hospital0'},
#   'display': 'hospital0'},
#  'date': '2023-05-25T15:04:30+00:00',
#  'reporter': {'reference': 'Organization/WA-DOH',
#   'display': 'Washington State Department of Health'},
#  'period': {'start': '2021-01-01T00:00:00+00:00',
#   'end': '2021-01-01T23:59:59+00:00'},
#  'group': [{'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasureGroupSystem',
#       'code': 'Beds'}],
#     'text': 'Hospital Bed Reporting'},
#    'population': [{'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numTotBeds'},
#        {'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#         'code': 'initial-population'}],
#       'text': 'Total number of all Inpatient and outpatient beds, including all staffed, ICU, licensed, and overflow(surge) beds used for inpatients or outpatients.'},
#      'count': 0},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numbeds'}],
#       'text': 'Inpatient beds, including all staffed, licensed, and overflow(surge) beds used for inpatients.'},
#      'count': 0},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numBedsOcc'}],
#       'text': 'Total number of staffed inpatient beds that are occupied.'},
#      'count': 108},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numICUBeds'}],
#       'text': 'Total number of staffed inpatient intensive care unit (ICU) beds.'},
#      'count': 0},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numICUBedsOcc'}],
#       'text': 'Total number of staffed inpatient ICU beds that are occupied.'},
#      'count': 64}]},
#   {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasureGroupSystem',
#       'code': 'Ventilators'}],
#     'text': 'Hospital Ventilator Reporting'},
#    'population': [{'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numVent'},
#        {'system': 'http://terminology.hl7.org/CodeSystem/measure-population',
#         'code': 'initial-population'}],
#       'text': 'Total number of ventilators available.'},
#      'count': 21},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numVentUse'}],
#       'text': 'Total number of ventilators in use.'},
#      'count': 25}]},
#   {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasureGroupSystem',
#       'code': 'Encounters'}],
#     'text': 'Hospital COVID-19 Encounters Reporting'},
#    'population': [{'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numC19HospPats'}],
#       'text': 'Patients currently hospitalized in an inpatient care location who have suspected or confirmed COVID-19.'},
#      'count': 62},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numC19MechVentPats'}],
#       'text': 'Patients hospitalized in an NHSN inpatient care location who have suspected or confirmed COVID-19 and are on a mechanical ventilator.'},
#      'count': 3},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numC19HOPats'}],
#       'text': 'Patients hospitalized in an NHSN inpatient care location with onset of suspected or confirmed COVID - 19 14 or more days after hospitalization.'},
#      'count': 24},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numC19OverflowPats'}],
#       'text': 'Patients with suspected or confirmed COVID-19 who are in the ED or any overflow location awaiting an inpatient bed.'},
#      'count': 25},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numC19OFMechVentPats'}],
#       'text': 'Patients with suspected or confirmed COVID - 19 who are in the ED or any overflow location awaiting an inpatient bed and on a mechanical ventilator.'},
#      'count': 22},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numC19Died'}],
#       'text': 'Patients with suspected or confirmed COVID-19 who died in the hospital, ED, or any overflow location.'},
#      'count': 16},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numC19Pats'}],
#       'text': 'Patients with suspected or confirmed COVID-19 in any location.'},
#      'count': 128},
#     {'code': {'coding': [{'system': 'http://hl7.org/fhir/uv/saner/CodeSystem/MeasuredValues',
#         'code': 'numC19VentPats'}],
#       'text': 'Ventilated COVID-19 Patients'},
#      'count': 25}]}]}

# %%
for entry in entries:
    measure = str.split(get_measure(entry['resource']), "/")[-1]
    if get_measure(entry['resource']) in measures_to_replace:
        updateEntry = deepcopy(entry)
        updateEntry['resource']['measure'] = 'https://cqf-ruler.ecqm.icfcloud.com/fhir/Measure/' + measure
        updateEntry.pop('search', None)
        updateEntry['request'] = {
            "method": "PUT",
            "url": f"{updateEntry['resource']['resourceType']}/{updateEntry['resource']['id']}"
        }
        updateBundle['entry'].append(updateEntry)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 for entry in entries:
# ----> 2     measure = str.split(get_measure(entry['resource']), "/")[-1]
#       3     if get_measure(entry['resource']) in measures_to_replace:
#       4         updateEntry = deepcopy(entry)
#
# KeyError: 'resource'

# %%
if len(updateBundle['entry']) > 0:
    url = base_url
    hed = {'Content-Type': 'application/json+fhir'}
    data = json.dumps(updateBundle)

    response = requests.post(url=url, data=data, headers=hed)
    print(response.text)
    print(response.status_code)
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "29ee2539-8a15-4098-a443-e2364d2276d6",
#   "type": "transaction-response",
#   "link": [ {
#     "relation": "self",
#     "url": "https://fhir.agg-data.connectathon.dev.cirg.uw.edu/fhir"
#   } ],
#   "entry": [ {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1761/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1763/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1764/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1765/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1766/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1767/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1768/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1770/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1771/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1772/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1773/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1774/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1775/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1776/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1777/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1778/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1779/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1780/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1781/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1783/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1782/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1784/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1785/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1786/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1787/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1788/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1789/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1790/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1791/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1792/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1793/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1794/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1795/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1796/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1797/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1798/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1799/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1800/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1801/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1802/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1803/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1804/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1805/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1806/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1807/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1808/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1809/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1810/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1811/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1812/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1813/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1814/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1815/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1816/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1817/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1818/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1819/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1820/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1821/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1822/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1823/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1824/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1825/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1826/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1827/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1828/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1829/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1830/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1831/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1832/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1833/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1834/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1835/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1836/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1837/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1838/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1839/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1840/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1841/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1842/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1843/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1844/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1845/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1846/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1847/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1848/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1849/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1850/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1851/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1852/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1853/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1854/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1855/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1856/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1857/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1858/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1859/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1860/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1861/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1862/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1863/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1864/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1865/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1866/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1867/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1868/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1869/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1870/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1871/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1872/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1873/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1874/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1875/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1876/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1877/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1878/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1879/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1880/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1881/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1882/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1883/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1884/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1885/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1886/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1887/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1888/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1889/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1890/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1891/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1892/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1893/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1894/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1895/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1896/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1897/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1898/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1899/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1900/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1901/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1902/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1903/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1904/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1905/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1906/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1907/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1908/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1909/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1910/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1911/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1912/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1913/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1914/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1915/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1916/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1917/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1918/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1919/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1920/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1921/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1922/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1923/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1924/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1925/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1926/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1927/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1928/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1929/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1930/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1931/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1932/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1933/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1934/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1935/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1936/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1937/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1938/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1939/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1940/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1953/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1954/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1955/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1956/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1957/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1958/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1959/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1960/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1961/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1962/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1963/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1964/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1965/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1966/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1967/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1968/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1969/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1970/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1971/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1972/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1973/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1974/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1975/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1976/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1978/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1979/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1980/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1981/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1982/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1983/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1984/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1985/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1986/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1987/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1988/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1989/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1990/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1991/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1992/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1993/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1994/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/1995/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2028/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2029/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2030/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2031/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2032/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2033/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2095/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2096/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2097/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2098/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2099/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2100/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2101/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2102/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2103/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2104/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2105/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2106/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2107/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2108/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2109/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2110/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2111/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2112/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2113/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2114/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   }, {
#     "response": {
#       "status": "200 OK",
#       "location": "MeasureReport/2115/_history/4",
#       "etag": "4",
#       "lastModified": "2023-05-10T19:43:16.233+00:00"
#     }
#   } ]
# }
# 200
